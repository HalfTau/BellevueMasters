# %%
import pandas as pd

data = {
    "name": ["Alice", "Bob", "Charlie", "Dana", "Eve"],
    "age": [24, 30, 29, 35, 22],
    "city": ["Seattle", "Tacoma", "Bremerton", "Seattle", "Tacoma"],
    "score": [88, 92, 95, 70, 85],
}

df = pd.DataFrame(data)
df
# Out:
#       name  age       city  score
# 0    Alice   24    Seattle     88
# 1      Bob   30     Tacoma     92
# 2  Charlie   29  Bremerton     95
# 3     Dana   35    Seattle     70
# 4      Eve   22     Tacoma     85

# %%
df.head()      # first 5 rows
df.info()      # column types + missing data
df.describe()  # numerical summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   age     5 non-null      int64
#  2   city    5 non-null      object
#  3   score   5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes
#              age      score
# count   5.000000   5.000000
# mean   28.000000  86.000000
# std     5.147815   9.721111
# min    22.000000  70.000000
# 25%    24.000000  85.000000
# 50%    29.000000  88.000000
# 75%    30.000000  92.000000
# max    35.000000  95.000000

# %%
df["name"]               # a Series
df[["name", "city"]]     # a DataFrame
# Out:
#       name       city
# 0    Alice    Seattle
# 1      Bob     Tacoma
# 2  Charlie  Bremerton
# 3     Dana    Seattle
# 4      Eve     Tacoma

# %%
df["name"]
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3       Dana
# 4        Eve
# Name: name, dtype: object

# %%
df[["name", "city"]]
# Out:
#       name       city
# 0    Alice    Seattle
# 1      Bob     Tacoma
# 2  Charlie  Bremerton
# 3     Dana    Seattle
# 4      Eve     Tacoma

# %%
df.head()
# Out:
#       name  age       city  score
# 0    Alice   24    Seattle     88
# 1      Bob   30     Tacoma     92
# 2  Charlie   29  Bremerton     95
# 3     Dana   35    Seattle     70
# 4      Eve   22     Tacoma     85

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   age     5 non-null      int64
#  2   city    5 non-null      object
#  3   score   5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
df[df["age"] > 25]            # ages over 25
df[df["city"] == "Seattle"]   # Seattle people
# Out:
#     name  age     city  score
# 0  Alice   24  Seattle     88
# 3   Dana   35  Seattle     70

# %%
df[df["age"] > 25]
# Out:
#       name  age       city  score
# 1      Bob   30     Tacoma     92
# 2  Charlie   29  Bremerton     95
# 3     Dana   35    Seattle     70

# %%
df["is_high_score"] = df["score"] >= 90

# %%
df.head()
# Out:
#       name  age       city  score  is_high_score
# 0    Alice   24    Seattle     88          False
# 1      Bob   30     Tacoma     92           True
# 2  Charlie   29  Bremerton     95           True
# 3     Dana   35    Seattle     70          False
# 4      Eve   22     Tacoma     85          False

# %%
df.sort_values("score", ascending=False)
# Out:
#       name  age       city  score  is_high_score
# 2  Charlie   29  Bremerton     95           True
# 1      Bob   30     Tacoma     92           True
# 0    Alice   24    Seattle     88          False
# 4      Eve   22     Tacoma     85          False
# 3     Dana   35    Seattle     70          False

# %%
df.head()
# Out:
#       name  age       city  score  is_high_score
# 0    Alice   24    Seattle     88          False
# 1      Bob   30     Tacoma     92           True
# 2  Charlie   29  Bremerton     95           True
# 3     Dana   35    Seattle     70          False
# 4      Eve   22     Tacoma     85          False

# %%
df = df.sort_values("score", ascending=False)

# %%
df.head()
# Out:
#       name  age       city  score  is_high_score
# 2  Charlie   29  Bremerton     95           True
# 1      Bob   30     Tacoma     92           True
# 0    Alice   24    Seattle     88          False
# 4      Eve   22     Tacoma     85          False
# 3     Dana   35    Seattle     70          False

# %%
df["is_high_score"].value_counts()
# Out:
# is_high_score
# False    3
# True     2
# Name: count, dtype: int64

# %%
df.groupby("city")["score"].mean()
# Out:
# city
# Bremerton    95.0
# Seattle      79.0
# Tacoma       88.5
# Name: score, dtype: float64

# %%
df.groupby("city")[["age", "score"]].mean()
# Out:
#             age  score
# city
# Bremerton  29.0   95.0
# Seattle    29.5   79.0
# Tacoma     26.0   88.5

# %%
df.loc[1, "score"] = None

# %%
df
# Out:
#       name  age       city  score  is_high_score
# 2  Charlie   29  Bremerton   95.0           True
# 1      Bob   30     Tacoma    NaN           True
# 0    Alice   24    Seattle   88.0          False
# 4      Eve   22     Tacoma   85.0          False
# 3     Dana   35    Seattle   70.0          False

# %%
df_filled = df.fillna(df["score"].mean())

# %%
df
# Out:
#       name  age       city  score  is_high_score
# 2  Charlie   29  Bremerton   95.0           True
# 1      Bob   30     Tacoma    NaN           True
# 0    Alice   24    Seattle   88.0          False
# 4      Eve   22     Tacoma   85.0          False
# 3     Dana   35    Seattle   70.0          False

# %%
df_dropped = df.dropna()

# %%
df
# Out:
#       name  age       city  score  is_high_score
# 2  Charlie   29  Bremerton   95.0           True
# 1      Bob   30     Tacoma    NaN           True
# 0    Alice   24    Seattle   88.0          False
# 4      Eve   22     Tacoma   85.0          False
# 3     Dana   35    Seattle   70.0          False

# %%
df = df_filled

# %%
df
# Out:
#       name  age       city  score  is_high_score
# 2  Charlie   29  Bremerton   95.0           True
# 1      Bob   30     Tacoma   84.5           True
# 0    Alice   24    Seattle   88.0          False
# 4      Eve   22     Tacoma   85.0          False
# 3     Dana   35    Seattle   70.0          False

# %%
df_dropped
# Out:
#       name  age       city  score  is_high_score
# 2  Charlie   29  Bremerton   95.0           True
# 0    Alice   24    Seattle   88.0          False
# 4      Eve   22     Tacoma   85.0          False
# 3     Dana   35    Seattle   70.0          False

# %%
df_real = pd.read_csv("titanic.csv")

# %%
df_real.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
